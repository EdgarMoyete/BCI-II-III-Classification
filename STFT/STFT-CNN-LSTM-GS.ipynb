# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 26/07/20
# #### Clasificacion binaria de imagenes motoras en EEG con CNN-2D + LSTM
# ##### Caracteristicas = Espectrogramas STFT (3D)
# ##### Entrada de 90x17
# ##### Busqueda de cuadricula

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import time
from scipy.signal import spectrogram
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import (TimeDistributed, Conv2D, MaxPool2D, Flatten, LSTM,
                          Dense, Dropout)
from keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# para que este script funcione debe de decir 'channels_last', si dice 'channels_first' no sirve
K.image_data_format()
# Out:
# 'channels_last'

# %%
c3_train = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_train.csv", header=None).iloc[:, 0:768]
c4_train = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_train.csv", header=None).iloc[:, 1536:2304]
c3_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_test.csv", header=None).iloc[:, 0:768]
c4_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_test.csv", header=None).iloc[:, 1536:2304]

# %%
x_train = pd.concat([c3_train, c4_train], axis=1)
x_test = pd.concat([c3_test, c4_test], axis=1)

# %%
# x_train = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_train.csv", header=None)
# x_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_test.csv", header=None)
y_train = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/etiquetas_train.csv", header=None)
y_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/etiquetas_test.csv", header=None)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (140, 1536)
# (140, 1536)
# (140, 1)
# (140, 1)

# %%
x = pd.concat([x_train, x_test])
y = pd.concat([y_train, y_test])

# %%
print(x.shape)
print(y.shape)
# Out:
# (280, 1536)
# (280, 1)

# %%
# en caso de no tener el y_test se puede utilizar el x_test
n_samples = len(y)

print("n_samples:", n_samples)
# Out:
# n_samples: 280

# %%
# esto se podria calcular asi n_clases = len(np.unique(y)), la y puede ser train o test
n_classes = len(np.unique(y))

print("n_classes:", n_classes)
# Out:
# n_classes: 2

# %%
#unir 2 canales y 3 segundos
def unir_espectrogramas_vertical(data):
  fs = 128
  datos = np.zeros((data.shape[0],90,17))
  temporal = np.zeros((90,17))
  for i in range(data.shape[0]): #n muestras
    for j in range(2): #2 canales
      sig = data.iloc[i, j*768:(j+1)*768]
      sig = sig[32:416]
      #espectrograma de STFFT
      f, t, Sxx = spectrogram(sig, fs=128, window='hann', nperseg=128,
                              noverlap=112, nfft=256, scaling='spectrum')
      temporal[j*45:(j+1)*45, :] = Sxx[16:61, :]
    datos[i] = temporal
    if i % 100 == 0: #esto solo es para ver como avanza
      print(i)
  return datos

# %%
#llamar a unir_espectrogramas_vertical_resize(data)
inicio = time.time()

x = unir_espectrogramas_vertical(x)

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# 0
# 100
# 200
# Tiempo: 0.4567081928253174

# %%
print(x.shape)
# Out:
# (280, 90, 17)

# %%
print(np.max(x))
print(np.min(x))
print(np.mean(x))
# Out:
# 0.009925350444004888
# 6.89847106360668e-12
# 9.56369384998064e-05

# %%
# convertir de 3D a 5D
x = x.reshape((x.shape[0], 1, x.shape[1], x.shape[2], 1))

print(x.shape)
# Out:
# (280, 1, 90, 17, 1)

# %%
def CNN_LSTM(n_unidades, n_neuronas):
  model = Sequential()
  model.add(TimeDistributed(Conv2D(64, (3,3), activation='relu', padding='same'),
                            input_shape=x.shape[1:]))
  model.add(TimeDistributed(MaxPool2D((2,2))))
  model.add(TimeDistributed(Conv2D(64, (3,3), activation='relu', padding='same')))
  model.add(TimeDistributed(MaxPool2D((2,2))))
  model.add(TimeDistributed(Flatten()))
  model.add(LSTM(n_unidades, activation='tanh', dropout=0.5))
  model.add(Dense(n_neuronas, activation='relu'))
  model.add(Dense(n_classes, activation='softmax'))

  optimizer = Adam(lr=1e-4)
  model.compile(optimizer = optimizer,
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
clf = KerasClassifier(build_fn = CNN_LSTM, epochs=400, batch_size=36, verbose=0)

# %%
n_unidades = [4, 8, 16, 32]
n_neuronas = [16, 32, 64, 128, 256]
hiperparametros = dict(n_unidades = n_unidades,
                       n_neuronas = n_neuronas)

# %%
# 20 redes = 2416 seg
4*5
# Out:
# 20

# %%
grid = GridSearchCV(clf, hiperparametros, cv=5)

# %%
inicio = time.time()

grid.fit(x, y)

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Tiempo: 2416.804496049881

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_neuronas': 128, 'n_unidades': 32}
# 0.8285714268684388

# %%
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
        % (mean, std * 2, params))
# Out:
# 0.750 (+/-0.201) for {'n_neuronas': 16, 'n_unidades': 4}
# 0.779 (+/-0.192) for {'n_neuronas': 16, 'n_unidades': 8}
# 0.804 (+/-0.185) for {'n_neuronas': 16, 'n_unidades': 16}
# 0.800 (+/-0.188) for {'n_neuronas': 16, 'n_unidades': 32}
# 0.736 (+/-0.348) for {'n_neuronas': 32, 'n_unidades': 4}
# 0.789 (+/-0.201) for {'n_neuronas': 32, 'n_unidades': 8}
# 0.807 (+/-0.191) for {'n_neuronas': 32, 'n_unidades': 16}
# 0.804 (+/-0.182) for {'n_neuronas': 32, 'n_unidades': 32}
# 0.729 (+/-0.344) for {'n_neuronas': 64, 'n_unidades': 4}
# 0.811 (+/-0.171) for {'n_neuronas': 64, 'n_unidades': 8}
# 0.811 (+/-0.194) for {'n_neuronas': 64, 'n_unidades': 16}
# 0.821 (+/-0.168) for {'n_neuronas': 64, 'n_unidades': 32}
# 0.811 (+/-0.164) for {'n_neuronas': 128, 'n_unidades': 4}
# 0.807 (+/-0.165) for {'n_neuronas': 128, 'n_unidades': 8}
# 0.818 (+/-0.165) for {'n_neuronas': 128, 'n_unidades': 16}
# 0.829 (+/-0.151) for {'n_neuronas': 128, 'n_unidades': 32}
# 0.814 (+/-0.187) for {'n_neuronas': 256, 'n_unidades': 4}
# 0.818 (+/-0.164) for {'n_neuronas': 256, 'n_unidades': 8}
# 0.829 (+/-0.139) for {'n_neuronas': 256, 'n_unidades': 16}
# 0.825 (+/-0.142) for {'n_neuronas': 256, 'n_unidades': 32}

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Jul 27 00:26:45 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    29W /  70W |   1205MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

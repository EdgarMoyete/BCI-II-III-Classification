# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 27-07-20-26-08-20
# #### Clasificacion binaria de imagenes motoras en EEG con CNN-2D + LSTM
# #### Cargar modelo para evaluacion y predecir
# ##### Caracteristicas = Escalogramas CWT (3D)
# ##### Entrada de 90x384

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import time
import pywt
from sklearn.metrics import confusion_matrix
from keras.models import load_model

# %%
c3_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_test.csv", header=None).iloc[:, 0:768]
c4_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/MIEEG_test.csv", header=None).iloc[:, 1536:2304]

# %%
x_test = pd.concat([c3_test, c4_test], axis=1)

# %%
y_test = pd.read_csv("/content/drive/My Drive/BCI-II-III/Datos/etiquetas_test.csv", header=None)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (140, 1536)
# (140, 1)

# %%
#unir 2 canales y 3 segundos
def unir_escalogramas_vertical(data):
  fs = 128
  escalas = pywt.scale2frequency('cmor3-3', np.arange(8,30.5,0.5)) / (1/fs)
  datos = np.zeros((data.shape[0],90,384))
  temporal = np.zeros((90,384))
  for i in range(data.shape[0]): #n muestras
    for j in range(2): #2 canales
      sig = data.iloc[i, j*768:(j+1)*768]
      sig = sig[32:416]
      # escalograma CWT
      coef, freqs = pywt.cwt(sig, escalas, 'cmor3-3', sampling_period = (1 / fs))
      temporal[j*45:(j+1)*45, :] = abs(coef)
    datos[i] = temporal
    if i % 100 == 0: #esto solo es para ver como avanza
      print(i)
  return datos

# %%
#llamar a unir_escalogramas_vertical(data)
x_test = unir_escalogramas_vertical(x_test)
# Out:
# 0
# 100

# %%
print(x_test.shape)
# Out:
# (140, 90, 384)

# %%
#convertir de 3D a 5D
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1], x_test.shape[2], 1))

print(x_test.shape)
# Out:
# (140, 1, 90, 384, 1)

# %%
model = load_model('/content/drive/My Drive/BCI-II-III/Modelos/CWT_RNN.hdf5')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_16 (TimeDis (None, 1, 90, 384, 8)     80
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 1, 45, 192, 8)     0
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 1, 45, 192, 8)     584
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 1, 22, 96, 8)      0
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 1, 16896)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 16)                1082432
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               2176
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 1,085,530
# Trainable params: 1,085,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
inicio = time.time()

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Tiempo: 0.8226804733276367

# %%
print("loss: %.4f" % test_loss)
print("accuracy: %.4f" % test_acc)
# Out:
# loss: 0.4236
# accuracy: 0.4857

# %%
probabilidades = model.predict(x_test)
y_pred = np.argmax(probabilidades, 1) #1=fila

# %%
matriz_confusion = confusion_matrix(y_test, y_pred)
print("confusion matrix:\n", matriz_confusion)
# Out:
# confusion matrix:
#  [[57 13]
#  [11 59]]

# %%
inicio = time.time()

probabilidades = model.predict(x_test[0].reshape(1,1,90,384,1))
y_pred = np.argmax(probabilidades, 1) #1=fila

fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Tiempo: 0.05733990669250488
